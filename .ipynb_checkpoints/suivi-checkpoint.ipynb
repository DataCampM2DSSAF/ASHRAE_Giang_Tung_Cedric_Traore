# %% [markdown]
# ## Objective for the week from 01 February to 07 February 2021
#
#  - Data mining
#  - Data processing and cleaning
#  - Descriptive statistics
#  - Proposal of a first model

# %% [markdown]
# #### First simple model using regression tree:
# - Measurement of type "Electricity" is kBTU, need to convert to kWh.
# - Removing some very large values of target variable.
# - Removing all variables contain NA.
# - Create one hot vector for "primary_use".

# %%
from IPython import display 
display.Image('.\Code\First_submission.png')

# %% [markdown]
# ## ## Objective for the week from 01 February to 07 February 2021
# - Studying more deeply target variable and relationship between the target variable and other variables
# - Exploratory Data Analysis
# - Considering handling missing data

# %% [markdown]
# First improvement compare to the first submission:
#     - Fill missing data Air_temperature
#     - Timestamps alignment
#     - Target transformation: log1p

# %%
from IPython import display 
display.Image('.\Code\Second_submission.png')

# %% [markdown]
#     - Filling all missing data
#     - IQR for target instead of meter_reading
#     - Study correllation between variables
